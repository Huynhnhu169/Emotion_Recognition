# %% [markdown]
# # Dataset Exploration
#
# Use this notebook for lightweight checks of the audio manifest. It does not train a model and does not embed raw audio outputs.

# %%
from pathlib import Path
import os
import sys

ROOT = Path.cwd()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

CONFIG_PATH = ROOT / 'configs' / 'emotion_model.yaml'

import pandas as pd
from src.data_split import load_config, load_manifest

config = load_config(CONFIG_PATH)
manifest = load_manifest(config)
manifest.head()

# %%
manifest['label'].value_counts().sort_index()

# %%
print(f"Original audio files: {len(manifest)}")
print(f"Classes: {sorted(manifest['label'].unique())}")
