# %% [markdown]
# # Single-File Inference Demo
#
# This notebook shows how to call the cleaned inference entry point after training. It intentionally does not start a public Gradio tunnel or embed audio outputs.

# %%
from pathlib import Path
import os
import sys

ROOT = Path.cwd()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

CONFIG_PATH = ROOT / 'configs' / 'emotion_model.yaml'

from src.data_split import load_config
from src.inference import predict

config = load_config(CONFIG_PATH)
# result = predict('path/to/audio.wav', config)
# result

# %%
# Terminal equivalent:
# python -m src.inference --config configs/emotion_model.yaml --audio path/to/audio.wav
